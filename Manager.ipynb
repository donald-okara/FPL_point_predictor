# %%
#Importing libraries

import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 
import requests

print("Libraries imported successfully......")

# %%
import pandas as pd
import requests

# Manager ID and Gameweek
manager_id = 1873280
GW = 1

# API URL to get the manager's team for a specific Gameweek
url = f"https://fantasy.premierleague.com/api/entry/{manager_id}/event/{GW}/picks/"

# Make the API request to get the manager's team
r = requests.get(url)
data = r.json()

# Create a list of dictionaries to store 'picks' along with metadata
picks_data = data.get('picks', [])  # Ensure 'picks' data is available

# Extract metadata
active_chip = data.get('active_chip')
automatic_subs = data.get('automatic_subs')
entry_history = data.get('entry_history')

# Create a list with metadata for each 'picks' element
data_list = []
for pick in picks_data:
    data_list.append({
        'active_chip': active_chip,
        'automatic_subs': automatic_subs,
        'entry_history': entry_history,
        **pick,  # Include the 'picks' data
    })

# Convert the list of dictionaries to a DataFrame
manager = pd.DataFrame(data_list)

# %%
manager
# Out:
#    active_chip automatic_subs  \
# 0         None             []
# 1         None             []
# 2         None             []
# 3         None             []
# 4         None             []
# 5         None             []
# 6         None             []
# 7         None             []
# 8         None             []
# 9         None             []
# 10        None             []
# 11        None             []
# 12        None             []
# 13        None             []
# 14        None             []
#
#                                         entry_history  element  position  \
# 0   {'event': 1, 'points': 63, 'total_points': 63,...      597         1
# 1   {'event': 1, 'points': 63, 'total_points': 63,...      290         2
# 2   {'event': 1, 'points': 63, 'total_points': 63,...       20         3
# 3   {'event': 1, 'points': 63, 'total_points': 63,...      195         4
# 4   {'event': 1, 'points': 63, 'total_points': 63,...      584         5
# 5   {'event': 1, 'points': 63, 'total_points': 63,...       12         6
# 6   {'event': 1, 'points': 63, 'total_points': 63,...      396         7
# 7   {'event': 1, 'points': 63, 'total_points': 63,...      373         8
# 8   {'event': 1, 'points': 63, 'total_points': 63,...      226         9
# 9   {'event': 1, 'points': 63, 'total_points': 63,...      355        10
# 10  {'event': 1, 'points': 63, 'total_points': 63,...      211        11
# 11  {'event': 1, 'points': 63, 'total_points': 63,...      230        12
# 12  {'event': 1, 'points': 63, 'total_points': 63,...      196        13
# 13  {'event': 1, 'points': 63, 'total_points': 63,...      139        14
# 14  {'event': 1, 'points': 63, 'total_points': 63,...      466        15
#
#     multiplier  is_captain  is_vice_captain
# 0            1       False            False
# 1            1       False            False
# 2            1       False            False
# 3            1       False            False
# 4            1       False            False
# 5            1       False            False
# 6            1       False            False
# 7            1       False             True
# 8            1       False            False
# 9            2        True            False
# 10           1       False            False
# 11           0       False            False
# 12           0       False            False
# 13           0       False            False
# 14           0       False            False

# %%
manager
