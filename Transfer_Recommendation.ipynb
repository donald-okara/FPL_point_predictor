# %%
import pandas as pd
import requests

# Manager ID and Gameweek
manager_id = 1873280
GW = 9
# API URL to get the manager's team for a specific Gameweek
url = f"https://fantasy.premierleague.com/api/entry/{manager_id}/event/{GW}/picks/"

# Make the API request to get the manager's team
r = requests.get(url)
data = r.json()

# Create a list of dictionaries to store 'picks' along with metadata
picks_data = data.get('picks', [])  # Ensure 'picks' data is available

# Extract metadata
active_chip = data.get('active_chip')
automatic_subs = data.get('automatic_subs')
entry_history = data.get('entry_history')

# Create a list with metadata for each 'picks' element
data_list = []
for pick in picks_data:
    data_list.append({
        'active_chip': active_chip,
        'automatic_subs': automatic_subs,
        'entry_history': entry_history,
        **pick,  # Include the 'picks' data
    })

# Convert the list of dictionaries to a DataFrame
manager = pd.DataFrame(data_list)

# %%
manager
# Out:
#    active_chip automatic_subs  \
# 0     wildcard             []
# 1     wildcard             []
# 2     wildcard             []
# 3     wildcard             []
# 4     wildcard             []
# 5     wildcard             []
# 6     wildcard             []
# 7     wildcard             []
# 8     wildcard             []
# 9     wildcard             []
# 10    wildcard             []
# 11    wildcard             []
# 12    wildcard             []
# 13    wildcard             []
# 14    wildcard             []
#
#                                         entry_history  element  position  \
# 0   {'event': 9, 'points': 84, 'total_points': 483...      230         1
# 1   {'event': 9, 'points': 84, 'total_points': 483...      519         2
# 2   {'event': 9, 'points': 84, 'total_points': 483...       36         3
# 3   {'event': 9, 'points': 84, 'total_points': 483...      311         4
# 4   {'event': 9, 'points': 84, 'total_points': 483...      430         5
# 5   {'event': 9, 'points': 84, 'total_points': 483...       19         6
# 6   {'event': 9, 'points': 84, 'total_points': 483...       52         7
# 7   {'event': 9, 'points': 84, 'total_points': 483...      516         8
# 8   {'event': 9, 'points': 84, 'total_points': 483...      308         9
# 9   {'event': 9, 'points': 84, 'total_points': 483...      355        10
# 10  {'event': 9, 'points': 84, 'total_points': 483...       60        11
# 11  {'event': 9, 'points': 84, 'total_points': 483...       28        12
# 12  {'event': 9, 'points': 84, 'total_points': 483...      403        13
# 13  {'event': 9, 'points': 84, 'total_points': 483...      139        14
# 14  {'event': 9, 'points': 84, 'total_points': 483...      466        15
#
#     multiplier  is_captain  is_vice_captain
# 0            1       False            False
# 1            1       False            False
# 2            1       False            False
# 3            1       False            False
# 4            1       False            False
# 5            1       False            False
# 6            1       False            False
# 7            1       False             True
# 8            1       False            False
# 9            2        True            False
# 10           1       False            False
# 11           0       False            False
# 12           0       False            False
# 13           0       False            False
# 14           0       False            False
